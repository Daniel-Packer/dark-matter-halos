# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from gw_distance_matrix import *
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from jax import numpy as jnp
rng = np.random.default_rng(seed=0)

root_path = Path("../..")
data_path = root_path / "data"

# %%
points, properties = pickle.load(open(data_path / "halos.pkl", 'rb'))
points_list = [p["Coordinates"] for p in points]

# %%
points_a = points[0]["Coordinates"]
# indices = points_a[:, 2] > 10_000
indices = np.arange(points_a.shape[0])
# plt.scatter(points_a[indices, 0], points_a[indices, 2], s=1)
px.scatter_3d(x=points_a[indices, 0], y=points_a[indices, 1], z=points_a[indices, 2], opacity=0.01)

# %%
subsample = 10
i = 20

points_rec = points[i]["Coordinates"] - points[i]["Coordinates"].mean(axis=0, keepdims=True)
points_norm = points_rec / 30
weights, pointcloud, labels = kmeans_subsample(points_norm, subsample, random_state=1, include_labels=True)
raw_points = points[i]["Coordinates"]
raw_points -= raw_points.mean(axis=0, keepdims=True)
raw_points /= 30


plt.scatter(raw_points[:, 0], raw_points[:, 2], s=1, alpha=0.1, c=labels, cmap="tab10")
plt.scatter(pointcloud.x[:,0 ], pointcloud.x[:, 2], alpha=1, s=weights * 500, c=np.arange(subsample), cmap="tab10")

# %%
kmeans_solns = do_experiment(points_list[4], points_list[6], num_trials=20, subsample=100, subsample_method="kmeans", method="gw")
uniform_solns = do_experiment(points_list[4], points_list[6], num_trials=20, subsample=100, subsample_method="uniform", method="gw")

# %%
fig, ax = plt.subplots(figsize=(12, 5))
uniform_costs = [soln.costs[soln.costs != -1][-1].item() for soln in uniform_solns]
kmeans_costs = [soln.costs[soln.costs != -1][-1].item() for soln in kmeans_solns]
sns.kdeplot(uniform_costs, label="Uniform", ax=ax)
sns.kdeplot(kmeans_costs, label="K-means", ax=ax)
ax.legend()
ax.set(title=f"Distribution of GW distances using different resampling methods\nNumber of samples: {100}", xlabel="GW distance")
# Out:
# [Text(0.5, 1.0, 'Distribution of GW distances using different resampling methods\nNumber of samples: 100'),
#  Text(0.5, 0, 'GW distance')]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# plt.hist([soln.primal_cost for soln in solns]);
np.savez('output.npz', mean_costs=mean_costs, std_costs=std_costs)

# %%
def get_distance_stats(num_trials, method="gw", use_k_means=False):
    solns = []
    for t in range(num_trials):
        rng = np.random.default_rng(seed=t)
        if use_k_means:
            kmeans = KMeans(n_clusters=subsample, random_state=t)
            kmeans.fit(points_a)
            pointcloud_a = pointcloud.PointCloud(kmeans.cluster_centers_)
            kmeans.fit(points_b)
            pointcloud_b = pointcloud.PointCloud(kmeans.cluster_centers_)

        else:
            indices_a = rng.choice(points_a.shape[0], subsample, replace=False)
            indices_b = rng.choice(points_b.shape[0], subsample, replace=False)

            pointcloud_a = pointcloud.PointCloud(points_a[indices_a])
            pointcloud_b = pointcloud.PointCloud(points_b[indices_b])

        prob = quadratic_problem.QuadraticProblem(pointcloud_a, pointcloud_b)
        match method:
            case "gw":
                solver = gromov_wasserstein.GromovWasserstein(epsilon=0.4)
            case "lb":
                solver = lower_bound.LowerBoundSolver(epsilon=0.5)
            case _:
                raise ValueError(f"Unknown method {method}")

        solns.append(solver(prob, max_iterations=10000))
    return solns

lb_trials = get_distance_stats(1, method="lb", use_k_means=True)
gw_trials = get_distance_stats(1, method="gw", use_k_means=True)
# Out:
# /home/daniel/mambaforge-pypy3/envs/pyot/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[94], line 31
#      28         solns.append(solver(prob, max_iterations=10000))
#      29     return solns
# ---> 31 lb_trials = get_distance_stats(1, method="lb", use_k_means=True)
#      32 gw_trials = get_distance_stats(1, method="gw", use_k_means=True)
#
# Cell In[94], line 7, in get_distance_stats(num_trials, method, use_k_means)
#       5 if use_k_means:
#       6     kmeans = KMeans(n_clusters=subsample, random_state=t)
# ----> 7     kmeans.fit(points_a)
#       8     pointcloud_a = pointcloud.PointCloud(kmeans.cluster_centers_)
#       9     kmeans.fit(points_b)
#
# File ~/mambaforge-pypy3/envs/pyot/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/mambaforge-pypy3/envs/pyot/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1515, in KMeans.fit(self, X, y, sample_weight)
#    1511 best_inertia, best_labels = None, None
#    1513 for i in range(self._n_init):
#    1514     # Initialize centers
# -> 1515     centers_init = self._init_centroids(
#    1516         X,
#    1517         x_squared_norms=x_squared_norms,
#    1518         init=init,
#    1519         random_state=random_state,
#    1520         sample_weight=sample_weight,
#    1521     )
#    1522     if self.verbose:
#    1523         print("Initialization complete")
#
# File ~/mambaforge-pypy3/envs/pyot/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1018, in _BaseKMeans._init_centroids(self, X, x_squared_norms, init, random_state, init_size, n_centroids, sample_weight)
#    1015     sample_weight = sample_weight[init_indices]
#    1017 if isinstance(init, str) and init == "k-means++":
# -> 1018     centers, _ = _kmeans_plusplus(
#    1019         X,
#    1020         n_clusters,
#    1021         random_state=random_state,
#    1022         x_squared_norms=x_squared_norms,
#    1023         sample_weight=sample_weight,
#    1024     )
#    1025 elif isinstance(init, str) and init == "random":
#    1026     seeds = random_state.choice(
#    1027         n_samples,
#    1028         size=n_clusters,
#    1029         replace=False,
#    1030         p=sample_weight / sample_weight.sum(),
#    1031     )
#
# File ~/mambaforge-pypy3/envs/pyot/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:255, in _kmeans_plusplus(X, n_clusters, x_squared_norms, sample_weight, random_state, n_local_trials)
#     252 np.clip(candidate_ids, None, closest_dist_sq.size - 1, out=candidate_ids)
#     254 # Compute distances to center candidates
# --> 255 distance_to_candidates = _euclidean_distances(
#     256     X[candidate_ids], X, Y_norm_squared=x_squared_norms, squared=True
#     257 )
#     259 # update closest distances squared and potential for each candidate
#     260 np.minimum(closest_dist_sq, distance_to_candidates, out=distance_to_candidates)
#
# File ~/mambaforge-pypy3/envs/pyot/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:379, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     376     distances = _euclidean_distances_upcast(X, XX, Y, YY)
#     377 else:
#     378     # if dtype is already float64, no need to chunk and upcast
# --> 379     distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     380     distances += XX
#     381     distances += YY
#
# File ~/mambaforge-pypy3/envs/pyot/lib/python3.11/site-packages/sklearn/utils/extmath.py:196, in safe_sparse_dot(a, b, dense_output)
#     192 else:
#     193     ret = a @ b
#     195 if (
# --> 196     sparse.issparse(a)
#     197     and sparse.issparse(b)
#     198     and dense_output
#     199     and hasattr(ret, "toarray")
#     200 ):
#     201     return ret.toarray()
#     202 return ret
#
# File ~/mambaforge-pypy3/envs/pyot/lib/python3.11/site-packages/scipy/sparse/_base.py:1461, in issparse(x)
#    1456     pass
#    1458 sparray.__doc__ = _spbase.__doc__
# -> 1461 def issparse(x):
#    1462     """Is `x` of a sparse array type?
#    1463
#    1464     Parameters
#    (...)
#    1485     False
#    1486     """
#    1487     return isinstance(x, _spbase)
#
# KeyboardInterrupt:

# %%
# plt.scatter([s.primal_cost.item() for s in lb_trials], [s.primal_cost.item() for s in gw_trials])
lb_trials[]
# Out:
# [SinkhornOutput(f=Array([-1.17285431e+02, -2.18293495e+01,  1.85374863e+02,  5.89875183e+01,
#          2.81285048e-02,  2.72381082e-02,  2.63473578e-02,  2.54573822e-02,
#          2.45742816e-02,  2.37006731e-02,  2.28352528e-02,  2.19822675e-02,
#          2.11510211e-02,  2.03402899e-02,  1.95478443e-02,  1.87842082e-02,
#          1.80445425e-02,  1.73262209e-02,  1.66384950e-02,  1.59759037e-02,
#          1.53382458e-02,  1.47250518e-02,  1.41342590e-02,  1.35687105e-02,
#          1.30245360e-02,  1.25039238e-02,  1.20054008e-02,  1.15271956e-02,
#          1.10676000e-02,  1.06290607e-02,  1.02067254e-02,  9.80183668e-03,
#          9.41299833e-03,  9.04289261e-03,  8.68733972e-03,  8.34575947e-03,
#          8.01916048e-03,  7.70611037e-03,  7.40611088e-03,  7.11533008e-03,
#          6.84170239e-03,  6.57509966e-03,  6.32323045e-03,  6.07937202e-03,
#          5.84613299e-03,  5.62320556e-03,  5.40593313e-03,  5.20283589e-03,
#          5.00601809e-03,  4.81652841e-03,  4.63476684e-03,  4.45907656e-03,
#          4.29322384e-03,  4.13161423e-03,  3.98189900e-03,  3.83295165e-03,
#          3.69284954e-03,  3.55543522e-03,  3.42568755e-03,  3.30155762e-03,
#          3.18100536e-03,  3.06809321e-03,  2.95713404e-03,  2.85212928e-03,
#          2.74856528e-03,  2.65309634e-03,  2.55630910e-03,  2.46844720e-03,
#          2.38071848e-03,  2.29901029e-03,  2.22077686e-03,  2.14370200e-03,
#          2.07012752e-03,  1.99985364e-03,  1.92914158e-03,  1.86568778e-03,
#          1.80270290e-03,  1.74341397e-03,  1.68446498e-03,  1.62883289e-03,
#          1.57668022e-03,  1.52572012e-03,  1.47555349e-03,  1.43031031e-03,
#          1.38161564e-03,  1.34107610e-03,  1.29812118e-03,  1.25525054e-03,
#          1.21928938e-03,  1.17976684e-03,  1.14309741e-03,  1.11025339e-03,
#          1.07562682e-03,  1.04363123e-03,  1.01260189e-03,  9.81934834e-04,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00,
#         -1.00000000e+00, -1.00000000e+00, -1.00000000e+00, -1.00000000e+00],      dtype=float32), reg_ot_cost=Array(121.314964, dtype=float32), ot_prob=<ott.problems.linear.linear_problem.LinearProblem object at 0x7fe85867a010>, threshold=Array(0.001, dtype=float32, weak_type=True), converged=Array(True, dtype=bool), inner_iterations=10)]

# %%
# for soln in lb_trials:
#     plt.plot(soln.costs[soln.costs != -1])
plt.hist([soln.primal_cost.item() for soln in lb_trials])
# Out:
# (array([2., 0., 3., 2., 3., 5., 1., 3., 0., 1.]),
#  array([14.50958061, 22.87479839, 31.24001617, 39.60523396, 47.97045174,
#         56.33566952, 64.7008873 , 73.06610508, 81.43132286, 89.79654064,
#         98.16175842]),
#  <BarContainer object of 10 artists>)

# %%
# for soln in gw_trials:
#     plt.plot(soln.costs[soln.costs != -1])
plt.hist([soln.primal_cost.item() for soln in gw_trials])
# Out:
# (array([1., 3., 2., 3., 4., 3., 2., 1., 0., 1.]),
#  array([ 39.5184021 ,  48.33645554,  57.15450897,  65.97256241,
#          74.79061584,  83.60866928,  92.42672272, 101.24477615,
#         110.06282959, 118.88088303, 127.69893646]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(lb_trials[0].matrix[1])

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].plot(soln.costs[soln.costs != -1])
axs[1].imshow(soln.matrix)
print(f"Converged: {soln.converged}")
# Out:
# Converged: True

# %%
plt.plot(soln.matrix[20])
